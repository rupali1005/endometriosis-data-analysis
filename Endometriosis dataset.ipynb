# %% [markdown]
# <H1> Introduction

# %% [markdown]
# <H3>Endometriosis is a chronic medical condition where tissue similar to the lining of the uterus, known as the endometrium, grows outside the
# uterine cavity. This aberrant growth can occur on various pelvic organs,including the ovaries, fallopian tubes, and the lining of the pelvic cavity.
# In rare instances, it may spread beyond the pelvic region.Globally, endometriosis affects approximately 10% of women of reproductive age.

# %% [markdown]
# <h2> Objective

# %% [markdown]
# <h4> The Objective of this project is to analyze an Endometriosis dataset to identify factors associated with diagnosis of Endometriosis.

# %%
#import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h2>Data Loading

# %%
df = pd.read_csv("C:/Users/KIIT/Desktop/Projects/Endometriosis dataset/structured_endometriosis_data.csv")

# %%
df
# Out:
#       Age  Menstrual_Irregularity  Chronic_Pain_Level  \
# 0      24                       1            8.361531
# 1      37                       1            4.995508
# 2      46                       1            3.363996
# 3      32                       1            5.246037
# 4      28                       1            3.898932
# ...   ...                     ...                 ...
# 9995   37                       1            3.153169
# 9996   44                       0            4.044800
# 9997   39                       0            5.096384
# 9998   47                       1            7.598862
# 9999   38                       0            7.822210
#
#       Hormone_Level_Abnormality  Infertility        BMI  Diagnosis
# 0                             0            0  19.451314          0
# 1                             0            0  22.388436          0
# 2                             1            0  21.320443          0
# ...

# %% [markdown]
# <h2> Understanding the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        10000 non-null  int64
#  1   Menstrual_Irregularity     10000 non-null  int64
#  2   Chronic_Pain_Level         10000 non-null  float64
#  3   Hormone_Level_Abnormality  10000 non-null  int64
#  4   Infertility                10000 non-null  int64
#  5   BMI                        10000 non-null  float64
#  6   Diagnosis                  10000 non-null  int64
# dtypes: float64(2), int64(5)
# memory usage: 547.0 KB

# %%
#no. of rows , columns
df.shape
# Out:
# (10000, 7)

# %%
#first 10 rows
df.head(10)
# Out:
#    Age  Menstrual_Irregularity  Chronic_Pain_Level  Hormone_Level_Abnormality  \
# 0   24                       1            8.361531                          0
# 1   37                       1            4.995508                          0
# 2   46                       1            3.363996                          1
# 3   32                       1            5.246037                          0
# 4   28                       1            3.898932                          1
# 5   25                       0            3.766540                          0
# 6   46                       1            5.866368                          0
# 7   38                       1            1.792541                          0
# 8   24                       0            2.112142                          1
# 9   43                       1            5.038582                          1
#
#    Infertility        BMI  Diagnosis
# 0            0  19.451314          0
# ...

# %%
#last 10 rows
df.tail(10)
# Out:
#       Age  Menstrual_Irregularity  Chronic_Pain_Level  \
# 9990   49                       1            4.150713
# 9991   21                       1            5.824441
# 9992   39                       0            4.763224
# 9993   35                       1            8.610709
# 9994   29                       1            6.172818
# 9995   37                       1            3.153169
# 9996   44                       0            4.044800
# 9997   39                       0            5.096384
# 9998   47                       1            7.598862
# 9999   38                       0            7.822210
#
#       Hormone_Level_Abnormality  Infertility        BMI  Diagnosis
# 9990                          1            0  27.286842          1
# 9991                          1            0  20.271897          1
# 9992                          1            1  31.852896          0
# 9993                          1            0  18.793566          0
# ...

# %%
#name of the columns
df.columns
# Out:
# Index(['Age', 'Menstrual_Irregularity', 'Chronic_Pain_Level',
#        'Hormone_Level_Abnormality', 'Infertility', 'BMI', 'Diagnosis'],
#       dtype='object')

# %%
#to know the datatypes of the columns
df.dtypes
# Out:
# Age                            int64
# Menstrual_Irregularity         int64
# Chronic_Pain_Level           float64
# Hormone_Level_Abnormality      int64
# Infertility                    int64
# BMI                          float64
# Diagnosis                      int64
# dtype: object

# %%
#the unique values of all the columns
df.nunique()
# Out:
# Age                            32
# Menstrual_Irregularity          2
# Chronic_Pain_Level           9875
# Hormone_Level_Abnormality       2
# Infertility                     2
# BMI                          9776
# Diagnosis                       2
# dtype: int64

# %% [markdown]
# <H2> Data Cleaning</H2>

# %%
#to check the null values
df.isnull().sum()
# Out:
# Age                          0
# Menstrual_Irregularity       0
# Chronic_Pain_Level           0
# Hormone_Level_Abnormality    0
# Infertility                  0
# BMI                          0
# Diagnosis                    0
# dtype: int64

# %%
#checking for the duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 Age  Menstrual_Irregularity  Chronic_Pain_Level  \
# count  10000.000000            10000.000000        10000.000000
# mean      33.692300                0.697500            5.030619
# std        9.205308                0.459364            1.983955
# min       18.000000                0.000000            0.000000
# 25%       26.000000                0.000000            3.671697
# 50%       34.000000                1.000000            5.035825
# 75%       42.000000                1.000000            6.396854
# max       49.000000                1.000000           10.000000
#
#        Hormone_Level_Abnormality   Infertility           BMI     Diagnosis
# count               10000.000000  10000.000000  10000.000000  10000.000000
# mean                    0.591100      0.298300     23.052865      0.407900
# std                     0.491655      0.457535      3.891615      0.491469
# min                     0.000000      0.000000     15.000000      0.000000
# ...

# %% [markdown]
# <H2> Exploratory Data Analysis(EDA)

# %%
#checking for outliers
plt.figure(figsize=(12,5))
sns.boxplot(data=df[['Age', 'Chronic_Pain_Level', 'BMI']])
plt.title("Checking for outliers")
plt.show()

# %%
#INTER QUARTILE METHOD
q1 = df['BMI'].quantile(0.25)
q2 = df['BMI'].quantile(0.5)
q3 = df['BMI'].quantile(0.75)
iqr = q3 - q1

# %%
upper_bound = q3 + 1.5*iqr
upper_bound
# Out:
# 33.78831759692971

# %%
#unique values in Diagnosis column
df["Diagnosis"].value_counts()
# Out:
# Diagnosis
# 0    5921
# 1    4079
# Name: count, dtype: int64

# %%
#to check correlation matrix among the numerical values
df.corr()
# Out:
#                                 Age  Menstrual_Irregularity  \
# Age                        1.000000               -0.007918
# Menstrual_Irregularity    -0.007918                1.000000
# Chronic_Pain_Level        -0.009348                0.000103
# Hormone_Level_Abnormality -0.004070                0.014647
# Infertility                0.014078               -0.012202
# BMI                       -0.011878                0.004868
# Diagnosis                 -0.011559                0.095197
#
#                            Chronic_Pain_Level  Hormone_Level_Abnormality  \
# Age                                 -0.009348                  -0.004070
# Menstrual_Irregularity               0.000103                   0.014647
# Chronic_Pain_Level                   1.000000                   0.002467
# Hormone_Level_Abnormality            0.002467                   1.000000
# Infertility                          0.009299                   0.003890
# ...

# %%
#rounding it to 2 decimal place
df.corr().round(2)
# Out:
#                             Age  Menstrual_Irregularity  Chronic_Pain_Level  \
# Age                        1.00                   -0.01               -0.01
# Menstrual_Irregularity    -0.01                    1.00                0.00
# Chronic_Pain_Level        -0.01                    0.00                1.00
# Hormone_Level_Abnormality -0.00                    0.01                0.00
# Infertility                0.01                   -0.01                0.01
# BMI                       -0.01                    0.00                0.01
# Diagnosis                 -0.01                    0.10                0.12
#
#                            Hormone_Level_Abnormality  Infertility   BMI  \
# Age                                            -0.00         0.01 -0.01
# Menstrual_Irregularity                          0.01        -0.01  0.00
# Chronic_Pain_Level                              0.00         0.01  0.01
# ...

# %% [markdown]
# <h2> Data Visualization</h2>

# %%
#Correlation Between Diagnosis & Other Factors
sns.heatmap(df.corr().round(2),annot = True, cmap = 'vlag')
# Out:
# <Axes: >

# %% [markdown]
# <H3> Hormone Level Abnormality and Chronic Pain have the highest correlation with Diagnosis.

# %% [markdown]
# <h3> BMI has the weakest correlation with Diagnosis.

# %%
#pair plot to show different features in the dataset
plt.figure(figure = (10,5))
sns.pairplot(df, hue = "Diagnosis", diag_kind = "kde")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.histplot(df,x="BMI",hue="Diagnosis",kde = True,bins = 30, color="orange")
plt.title("KDE plot for BMI Distribution with Diagnosis")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.histplot(df,x="Age", hue="Diagnosis",kde = True,bins = 30, color="Green")
plt.title("KDE plot of Age Distribution with Diagnosis")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.histplot(df,x="Chronic_Pain_Level",hue = "Diagnosis",kde = True,bins = 30, color="brown")
plt.title("KDE Plot Distribution of Chronic_Pain_Level with Diagnosis")
plt.ylabel("Frequency")
plt.show()

# %%
#Proportion of Diagnosed vs Undiagnosed 
df["Diagnosis"].value_counts().plot.pie(autopct="%1.1f%%", colors=["skyblue", "salmon"])
plt.title("Proportion of Diagnosed vs. Undiagnosed")
plt.ylabel("")
plt.show()

# %% [markdown]
# <h4>A larger undiagnosed slice suggests that a majority of patients have not been diagnosed.

# %%
#To Check if BMI and Chronic Pain Level are linked to Diagnosis
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["BMI"], y=df["Chronic_Pain_Level"], hue=df["Diagnosis"], palette="coolwarm")
plt.title("BMI vs. Chronic Pain Level by Diagnosis")
plt.show()

# %%
#Comparing pain levels between diagnosed and undiagnosed patients
plt.figure(figsize=(6, 4))
sns.boxplot(x=df["Diagnosis"], y=df["Chronic_Pain_Level"], palette="vlag")
plt.title("Chronic Pain Level by Diagnosis")
plt.xticks([0, 1], ["Undiagnosed", "Diagnosed"])
plt.show()
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_16816\2398443199.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Diagnosis"], y=df["Chronic_Pain_Level"], palette="vlag")

# %% [markdown]
# <H2> Conclusion

# %% [markdown]
# <h3>Based on my analysis, I extracted:
#
# <h4>Hormone Level Abnormalities and Chronic Pain Level appear to be the most Influential Factors in Endometrial Diagnosis.
#
#
# Menstrual Irregularity and BMI alone may not be the strong Indicators.
#
# The dataset has some outliers no extreme multicollinearity issues.
#
# I also found that most cases occurred within a specific age range, though age itself wasn't strongly correlated with Diagnosis.
